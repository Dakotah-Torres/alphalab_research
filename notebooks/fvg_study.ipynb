# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import adfuller

import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

from lab.fvg_study import FairValueGapDetector
from lab.high_low_study import HighLowDetector
sns.set_theme(style="whitegrid")

# %%
df = pd.read_csv('../db/raw_parque/January_MNQ.csv')
fvg = FairValueGapDetector(candles = df, threshold = 50, time_frame = '30min')
fvg.run_detector()
# Out:
#         high             high_ts       low              low_ts     type  \
# 0   25713.50 2026-01-08 15:00:00  25774.00 2026-01-08 14:00:00  bearish
# 1   25646.00 2026-01-08 19:30:00  25667.00 2026-01-08 20:30:00  bullish
# 2   25654.00 2026-01-09 01:30:00  25673.25 2026-01-09 02:30:00  bullish
# 3   25696.50 2026-01-09 09:00:00  25716.75 2026-01-09 10:00:00  bullish
# 4   25923.50 2026-01-09 18:00:00  25948.00 2026-01-09 19:00:00  bullish
# ..       ...                 ...       ...                 ...      ...
# 67  26130.25 2026-01-29 01:30:00  26147.50 2026-01-29 02:30:00  bullish
# 68  26200.00 2026-01-29 03:30:00  26214.50 2026-01-29 04:30:00  bullish
# 69  25868.50 2026-01-29 15:00:00  26131.75 2026-01-29 14:00:00  bearish
# 70  25753.50 2026-01-29 15:30:00  25858.25 2026-01-29 14:30:00  bearish
# 71  25881.50 2026-01-29 20:00:00  25948.00 2026-01-29 21:00:00  bullish
#
#     spread
# 0    242.0
# 1     84.0
# 2     77.0
# 3     81.0
# 4     98.0
# ..     ...
# 67    69.0
# ...

# %%
fvg.candles
# Out:
#             window_start ticker symbol contract_month  contract_year  \
# 0    2026-01-08 11:30:00  MNQH6    MNQ              H         2026.0
# 1    2026-01-08 12:00:00  MNQH6    MNQ              H         2026.0
# 2    2026-01-08 12:30:00  MNQH6    MNQ              H         2026.0
# 3    2026-01-08 13:00:00  MNQH6    MNQ              H         2026.0
# 4    2026-01-08 13:30:00  MNQH6    MNQ              H         2026.0
# ...                  ...    ...    ...            ...            ...
# 1029 2026-01-29 22:00:00    NaN    NaN            NaN            NaN
# 1030 2026-01-29 22:30:00    NaN    NaN            NaN            NaN
# 1031 2026-01-29 23:00:00  MNQH6    MNQ              H         2026.0
# 1032 2026-01-29 23:30:00  MNQH6    MNQ              H         2026.0
# 1033 2026-01-30 00:00:00  MNQH6    MNQ              H         2026.0
#
#       transactions      open      high       low     close session_end_date  \
# ...

# %%
fvg.visualize()

# %%
high_low = HighLowDetector(candles=df, time_frame='5min')

# %%
len(df)
# Out:
# 21143

# %%
high_low.run_detector()
high_low.visualize()
# Out:
# (            window_start ticker symbol contract_month  contract_year  \
#  3    2026-01-08 11:50:00  MNQH6    MNQ              H         2026.0
#  4    2026-01-08 11:55:00  MNQH6    MNQ              H         2026.0
#  5    2026-01-08 12:00:00  MNQH6    MNQ              H         2026.0
#  10   2026-01-08 12:25:00  MNQH6    MNQ              H         2026.0
#  11   2026-01-08 12:30:00  MNQH6    MNQ              H         2026.0
#  ...                  ...    ...    ...            ...            ...
#  6185 2026-01-29 23:00:00  MNQH6    MNQ              H         2026.0
#  6186 2026-01-29 23:05:00  MNQH6    MNQ              H         2026.0
#  6192 2026-01-29 23:35:00  MNQH6    MNQ              H         2026.0
#  6194 2026-01-29 23:45:00  MNQH6    MNQ              H         2026.0
#  6195 2026-01-29 23:50:00  MNQH6    MNQ              H         2026.0
#
#        transactions      open      high       low     close session_end_date  \
# ...
